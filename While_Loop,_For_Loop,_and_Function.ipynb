# %% [markdown]
# ## **Task 1: While Loop & Control Statements -Number Guessing Game**

# %%
import random

# Generate random number between 1 and 10
secret_number = random.randint(1, 10)

attempts = 3

print("Welcome to the Number Guessing Game!")
print("Guess a number between 1 and 10")
print("You have", attempts, "attempts.")

while attempts > 0:
    guess = input("Enter your guess: ")

    if not guess.isdigit():
        print("Please enter a valid number!")
        continue

    guess = int(guess)
    attempts -= 1

    if guess < 1 or guess > 10:
        print("Number must be between 1 and 10")


    if guess == secret_number:
        print("Congratulations! You guessed the correct number.")
        break

    elif guess < secret_number:
        print("Too low! Try again. Attempts left: " , attempts)

    else:
        print("Too high! Try again. Attempts left: " , attempts)

else:
    print("Game Over! You've used all attempts.")
    print("The secret number was:", secret_number)
# Out:
# Welcome to the Number Guessing Game!
# Guess a number between 1 and 10
# You have 3 attempts.
# Enter your guess: 5
# Too low! Try again. Attempts left:  2
# Enter your guess: 2
# Too low! Try again. Attempts left:  1
# Enter your guess: 9
# Too high! Try again. Attempts left:  0
# Game Over! You've used all 3 attempts.
# The secret number was: 6

# %% [markdown]
# ## **# Task 2:- For Loop - Multiplication Table Generator**

# %%
# enter a number
number = int(input("Enter a number: "))

# multiplication table from 1 to 10
for i in range(1, 11):
    result = number * i
    print(number, "x", i, "=", result)
# Out:
# Enter a number: 6
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60

# %% [markdown]
# ## **Task 3: Function- BMI Calculator**

# %%
# calculate BMI
def calculate_bmi(weight, height):
    bmi = weight / (height ** 2)
    return bmi

# Get user input
weight = float(input("Enter your weight in kg: "))
height = float(input("Enter your height in meters: "))

# Calculate BMI
bmi = calculate_bmi(weight, height)

# Display BMI
print("Your BMI is:", round(bmi, 2))
# Out:
# Enter your weight in kg: 58
# Enter your height in meters: 1.62
# Your BMI is: 22.1
